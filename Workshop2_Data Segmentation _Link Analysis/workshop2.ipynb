# %% [markdown]
# # <center>Workshop 2: Data Segmentation and Link Analysis  <center>

# %% [markdown]
# ### Import Libaries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.pyplot import rcParams
import seaborn as sn
# %matplotlib inline

# %% [markdown]
# ***
# # <center><font color=purple> ------------------- Clustering ------------------- </font></center>

# %% [markdown]
# ###Wine Data set
#
# **Data Set Characteristics:**
#
# Number of Instances:  178 (50 in each of three classes)
#
# Number of Attributes:  13 numeric attributes and the class
#
# Missing Attribute Values:  None
#
# Class Distribution:  class_0 (59), class_1 (71), class_2 (48)
#
# **Creator:**  R.A. Fisher
#
# **Donor:**  Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
#
# **Date:**  July, 1988
#
# **Description:**
#
# The data is the results of a chemical analysis of wines grown in the same region in Italy by three different cultivators. There are thirteen different measurements taken for different constituents found in the three types of wine.
#
# **Original Owners:**
#
# Forina, M. et al, PARVUS - An Extendible Package for Data Exploration, Classification and Correlation. Institute of Pharmaceutical and Food Analysis and Technologies, Via Brigata Salerno, 16147 Genoa, Italy.
#
# **Citation:**
#
# Lichman, M. (2013). UCI Machine Learning Repository [https://archive.ics.uci.edu/ml]. Irvine, CA: University of California, School of Information and Computer Science.
#
# (This is a copy of UCI ML Wine recognition datasets. https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data)

# %% [markdown]
# ### Import Wine dataset

# %% [markdown]
# ### Data Pre-Processing

# %% [markdown]
# ***
# # <center><font color=purple> K-means clustering </font></center>

# %% [markdown]
# ### Import related library (libraries)

# %% [markdown]
# __Parameter__
# - __n_clusters (default: 8)__ : The number of clusters to form as well as the number of centroids to generate.
#
# - __init (defaults: ‘k-means++’)__ : Method for initialization<br>
# 'k-means++' : selects initial cluster centers for k-mean clustering in a smart way to speed up convergence. [For more details](https://en.wikipedia.org/wiki/K-means%2B%2B).<br>
# 'random' : choose k observations (rows) at random from data for the initial centroids.
# - __max_iter (default: 300)__ : Maximum number of iterations of the k-means algorithm for a single run.
# - __random_state (default: None)__ : Determines random number generation for centroid initialization

# %% [markdown]
# ### Training model

# %% [markdown]
# ### Select number of clusters (k) using relavant plots

# %% [markdown]
# ###**In your opinion what is the right number of cluster and why do you think so ? (You can answer this question by typing in this blog in Thai or English)**
#
# (Note: The right number of cluster is not necessary the same as the number of available classes.)

# %% [markdown]
# ***
# # <center><font color=purple> Agglomerative Clustering </font></center>

# %% [markdown]
# ### Import related library (Libraries)

# %% [markdown]
# ### Training model

# %% [markdown]
# ### Select number of clusters (k) using relavant plots

# %% [markdown]
# ### **In your opinion what is the right number of cluster and why do you think so ? (You can answer this question by typing in this blog in Thai or English)**
# (Note: The right number of cluster is not necessary the same as the number of available classes.)

# %% [markdown]
# ***
# # <center><font color=purple> ------------------- Basket Analysis  -------------------</font></center>

# %% [markdown]
# ### France Retail Data Set
#
# **Data Set Information:**
#
# This Online Retail data set contains all the transactions occurring for a UK-based and registered, non-store online retail between 01/12/2009 and 09/12/2011.The company mainly sells unique all-occasion gift-ware. Many customers of the company are wholesalers.
#
# **Attribute Information:**
#
# **InvoiceNo:** Invoice number. Nominal. A 6-digit integral number uniquely assigned to each transaction. If this code starts with the letter 'c', it indicates a cancellation.
#
# **StockCode:** Product (item) code. Nominal. A 5-digit integral number uniquely assigned to each distinct product.
#
# **Description:** Product (item) name. Nominal.
#
# **Quantity:** The quantities of each product (item) per transaction. Numeric.
#
# **InvoiceDate:** Invice date and time. Numeric. The day and time when a transaction was generated.
#
# **UnitPrice:** Unit price. Numeric. Product price per unit in sterling (£).
#
# **CustomerID:** Customer number. Nominal. A 5-digit integral number uniquely assigned to each customer.
#
# **Country:** Country name. Nominal. The name of the country where a customer resides.
#
# **Source:** UCL and  Dr Daqing Chen, Director: Public Analytics group. chend '@' lsbu.ac.uk, School of Engineering, London South Bank University, London SE1 0AA, UK.

# %% [markdown]
# ### Import dataset

# %% [markdown]
# ### Reshape dataset

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# ### Find Association Rules

# %% [markdown]
# ### Generate the rules with Corresponding support, confidence and lift

# %% [markdown]
# ### **In your opinion, which are the three top true association rules that you will choose for use in the promotion and why ?**
